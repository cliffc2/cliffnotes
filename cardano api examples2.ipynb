# %%
#this is a cardano api test
#https://medium.com/@randerson112358/get-bitcoin-price-in-real-time-using-python-98b7393b6152

#Import the requests library
import requests

TICKER_API_URL = 'https://api.coinmarketcap.com/v1/ticker/'

def get_latest_crypto_price(crypto):
  
  response = requests.get(TICKER_API_URL+crypto)
  response_json = response.json()
  
  return float(response_json[0]['price_usd'])


#Test the function to see if it returns the current price of the crypto currency.
get_latest_crypto_price('cardano')

#https://min-api.cryptocompare.com/data/price?fsym=ADA&tsyms=BTC,USD,JPY,EUR,HKD
# Out:
# 0.0385329377

# %%
#this is a bitcoin api test
#https://medium.com/@randerson112358/get-bitcoin-price-in-real-time-using-python-98b7393b6152

#Import the requests library
import requests

TICKER_API_URL = 'https://api.coinmarketcap.com/v1/ticker/'

def get_latest_crypto_price(crypto):
  
  response = requests.get(TICKER_API_URL+crypto)
  response_json = response.json()
  
  return float(response_json[0]['price_usd'])


#Test the function to see if it returns the current price of the crypto currency.
get_latest_crypto_price('bitcoin')
# Out:
# 7696.48527006

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('ada.csv') 

fig = px.line(df, x='date', y='CapMrktCurUSD') 
fig.show()
# Out:
# <div>
#
#
#             <div id="3ccfa323-94ce-4405-a611-8361156e8d30" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3ccfa323-94ce-4405-a611-8361156e8d30")) {
#                     Plotly.newPlot(
#                         '3ccfa323-94ce-4405-a611-8361156e8d30',
# ...

# %%
#get $ADA price in BTC,USD,JPY,EUR,HKD
import requests
import json

#loads json data into response
response = requests.get('https://min-api.cryptocompare.com/data/price?fsym=ADA&tsyms=BTC,USD,JPY,EUR,HKD')
  
print(response.json())
# Out:
# {'BTC': 4.35e-06, 'USD': 0.04069, 'JPY': 4.4, 'EUR': 0.0365, 'HKD': 0.3182}

# %%
#response = requests.post(url, data=json.dumps(parameters), headers=headers)
#print(response)
#print(response.text)

# %%
import requests

response = requests.get('https://min-api.cryptocompare.com/data/price?fsym=ADA&tsyms=BTC,USD,JPY,EUR,HKD')
#https://min-api.cryptocompare.com/data/top/totalvol?limit=10&tsym=USD
print(response)
print(response.text)
# Out:
# <Response [200]>
# {"BTC":0.00000435,"USD":0.04069,"JPY":4.4,"EUR":0.0365,"HKD":0.3182}

# %%
import requests

response = requests.get('https://min-api.cryptocompare.com/data/top/totalvol?limit=10&tsym=USD')
#https://min-api.cryptocompare.com/data/top/totalvol?limit=10&tsym=USD
print(response)
print(response.text)
# Out:
# <Response [200]>
# ...

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('ADA-USD.csv') #df2 = pd.read_csv('btc.csv')

df.head
#fig = px.line(df, x='date', y='Close') #fig2 = px.line(df, x='date', y='FeeMeanUSD')
#fig.show()
# Out:
# <bound method NDFrame.head of            Date      Open      High       Low     Close  Adj Close    Volume
# 0    23/10/2018  0.075864  0.076139  0.073072  0.074743   0.074743  20710600
# 1    24/10/2018  0.074612  0.075652  0.074150  0.074321   0.074321  14151400
# 2    25/10/2018  0.074289  0.074345  0.073163  0.073859   0.073859  12567300
# 3    26/10/2018  0.073748  0.073960  0.072679  0.073713   0.073713  13464800
# 4    27/10/2018  0.073687  0.073791  0.072868  0.072886   0.072886  10316000
# ..          ...       ...       ...       ...       ...        ...       ...
# 360  18/10/2019  0.039527  0.039594  0.037591  0.038073   0.038073  39606481
# 361  19/10/2019  0.038079  0.039672  0.037832  0.039225   0.039225  40431590
# 362  20/10/2019  0.039217  0.039619  0.038443  0.039529   0.039529  33137956
# 363  21/10/2019  0.039543  0.039559  0.038694  0.039280   0.039280  36963295
# 364  23/10/2019  0.038815  0.038815  0.038657  0.038657   0.038657  39229288
#
# ...

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('ADA-USD.csv') 

df.info()

#fig = px.line(df, x='date', y='CapMrktCurUSD') 
#fig.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
# Date         365 non-null object
# Open         365 non-null float64
# High         365 non-null float64
# Low          365 non-null float64
# Close        365 non-null float64
# Adj Close    365 non-null float64
# Volume       365 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 20.1+ KB

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('ADA-USD.csv')

fig = px.line(df, x='Date', y='Close') 
fig.show()
# Out:
# <div>
#
#
#             <div id="32b4a61d-1284-45d7-8bc4-5312e197b5af" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("32b4a61d-1284-45d7-8bc4-5312e197b5af")) {
#                     Plotly.newPlot(
#                         '32b4a61d-1284-45d7-8bc4-5312e197b5af',
# ...

# %%
import plotly.express as px
import pandas as pd

#df = pd.read_csv('ADA-USD.csv')
df2 = pd.read_csv('btc.csv')

fig = px.line(df, x='Date', y='Close') 
#fig = px.line(df2, x='date', y='PriceUSD') 
fig.show()
# Out:
# <div>
#
#
#             <div id="091246cc-f283-4ea5-bd16-c3f7a3790ccf" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("091246cc-f283-4ea5-bd16-c3f7a3790ccf")) {
#                     Plotly.newPlot(
#                         '091246cc-f283-4ea5-bd16-c3f7a3790ccf',
# ...

# %%
import pandas as pd
import matplotlib.transforms as mtransforms
import matplotlib.pyplot as plt
import numpy as np

url = 'https://fred.stlouisfed.org/graph/fredgraph.csv?id=VIXCLS'
vix = pd.read_csv(url, index_col=0, parse_dates=True, na_values='.',
                   infer_datetime_format=True,
                   squeeze=True).dropna()
ma = vix.rolling('90d').mean()
state = pd.cut(ma, bins=[-np.inf, 14, 18, 24, np.inf],
                labels=range(4))
cmap = plt.get_cmap('RdYlGn_r')
ma.plot(color='black', linewidth=1.5, marker='', figsize=(8, 4),
         label='VIX 90d MA')
ax = plt.gca()  # Get the current Axes that ma.plot() references
ax.set_xlabel('')
ax.set_ylabel('90d moving average: CBOE VIX')
ax.set_title('Volatility Regime State')
ax.grid(False)
ax.legend(loc='upper center')
ax.set_xlim(xmin=ma.index[0], xmax=ma.index[-1])

trans = mtransforms.blended_transform_factory(ax.transData, ax.transAxes)
for i, color in enumerate(cmap([0.2, 0.4, 0.6, 0.8])):
    ax.fill_between(ma.index, 0, 1, where=state==i, facecolor=color, transform=trans)
    ax.axhline(vix.mean(), linestyle='dashed', color='xkcd:dark grey', alpha=0.6, label='Full-period mean', marker='')

# %%
import plotly.express as px
import pandas as pd

df = pd.read_csv('BTC-ADA-USD.csv')

df
# Out:
#            Date         Open         High          Low        Close  \
# 0    25/10/2018  6484.649902  6504.649902  6447.029785  6476.290039
# 1    26/10/2018  6468.439941  6498.290039  6449.609863  6474.750000
# 2    27/10/2018  6480.839844  6507.410156  6453.529785  6480.379883
# 3    28/10/2018  6482.660156  6502.279785  6447.910156  6486.390137
# 4    29/10/2018  6492.350098  6503.600098  6306.990234  6332.629883
# ..          ...          ...          ...          ...          ...
# 361  21/10/2019  8225.115234  8296.694336  8196.416016  8243.720703
# 362  22/10/2019  8243.402344  8296.651367  8074.462891  8078.203125
# 363  23/10/2019  8076.228516  8092.999512  7469.322754  7514.671875
# 364  24/10/2019  7509.728027  7532.867676  7446.988770  7493.488770
# 365  25/10/2019  7491.186035  7590.730957  7482.688477  7590.730957
#
#        Adj Close       Volume       Date2        op        hi        lo  \
# 0    6476.290039   3230550000  25/10/2018  0.074289  0.074345  0.073163
# ...

# %%
import plotly.graph_objects as go
#import plotly.express as px
import pandas as pd
from plotly.subplots import make_subplots

df = pd.read_csv('BTC-ADA-USD.csv')

#df
fig = go.Figure()
fig = make_subplots(rows=1, cols=1, shared_xaxes=True)
#fig = px.line(df, x='Date', y='Close')
g = df['clos'] * 100000
g

fig.add_trace(go.Scatter(x=df["Date"], y=df["Close"], mode="lines", name="bitcoin"), row=1, col=1)
fig.add_trace(go.Scatter(x=df["Date"], y=(df['clos']*100000), mode="lines", name="cardano"), row=1, col=1)
#fig.add_trace(go.Scatter(x=df["Date"], y=(1000*df['clos']), mode="lines"), row=1, col=1) 

fig.update_layout(title='btc vs ada graph juxtaposed for movement study',
                   xaxis_title='date',
                   yaxis_title='price')
fig.show()
# Out:
# <div>
#
#
#             <div id="ce4f57af-ebd4-4bd5-ab04-2e7c006933bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ce4f57af-ebd4-4bd5-ab04-2e7c006933bd")) {
#                     Plotly.newPlot(
#                         'ce4f57af-ebd4-4bd5-ab04-2e7c006933bd',
# ...

# %%
import datetime as dt                                                              
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
style.use('ggplot')
df = pd.read_csv('btc.csv', parse_dates=True, index_col=0)
df = df.round(decimals=2)df['200ma'] = df['PriceUSD'].rolling(window=200, min_periods=0).mean().round(decimals=2)axis1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
axis1.plot(df.index, df['PriceUSD'])
axis1.plot(df.index, df['200ma'])plt.show()
# Out:
#   File "<ipython-input-25-45ddfb129b03>", line 8
#     df = df.round(decimals=2)df['200ma'] = df['PriceUSD'].rolling(window=200, min_periods=0).mean().round(decimals=2)axis1 = plt.subplot2grid((6,1), (0,0), rowspan=5, colspan=1)
#                               ^
# SyntaxError: invalid syntax

# %%
import datetime as dt                                                              
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
style.use('ggplot')
df = pd.read_csv('btc.csv', parse_dates=True)
print(df.head())

#df['200ma'] = df['clos'].rolling(window=200)
df['200ma'] = df['PriceUSD'].rolling(window=200).mean()
print(df.head())
# Out:
#          date  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 0  2009-01-03          0       0            0              NaN         NaN
# 1  2009-01-04          0       0            0              NaN         NaN
# 2  2009-01-05          0       0            0              NaN         NaN
# 3  2009-01-06          0       0            0              NaN         NaN
# 4  2009-01-07          0       0            0              NaN         NaN
#
#    CapMrktCurUSD  CapRealUSD  DiffMean  FeeMeanNtv  ...  TxTfrValAdjUSD  \
# 0            NaN         0.0       NaN         NaN  ...             NaN
# 1            NaN         0.0       NaN         NaN  ...             NaN
# 2            NaN         0.0       NaN         NaN  ...             NaN
# 3            NaN         0.0       NaN         NaN  ...             NaN
# 4            NaN         0.0       NaN         NaN  ...             NaN
#
#    TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  TxTfrValMedUSD  \
# ...
